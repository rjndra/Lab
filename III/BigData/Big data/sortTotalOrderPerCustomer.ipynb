# %%
# %%writefile customerMapper.py
from mrjob.job import MRJob
from mrjob.job import MRStep

class BigData(MRJob):

    def steps(self):
        step1 = MRStep(mapper = self.mapper_first, reducer = self.reducer_first)
        step2 = MRStep(mapper = self.mapper_second, reducer = self.reducer_second)
        return [step1,step2]

    def mapper_first(self, key, value):
        (cust_id, order_id, price) = value.split(",")
        yield cust_id, float(price)

    def reducer_first(self, cust_id, amount):
        yield cust_id,sum(amount)

    def mapper_second(self, cust_id, amount):
        yield amount, cust_id

    def reducer_second(self, amount, cust_id):
        for id in cust_id:
            yield amount, id

if __name__ == "__main__":
    BigData.run()
# Out:
# Overwriting customerMapper.py

# %%
# !python customerMapper.py customer-orders.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /var/folders/dw/6724ln6d2q90v9g8cw4gbcp00000gn/T/customerMapper.rajendrakarki.20240208.013509.970251
# Running step 1 of 2...
# Running step 2 of 2...
# job output is in /var/folders/dw/6724ln6d2q90v9g8cw4gbcp00000gn/T/customerMapper.rajendrakarki.20240208.013509.970251/output
# Streaming final output from /var/folders/dw/6724ln6d2q90v9g8cw4gbcp00000gn/T/customerMapper.rajendrakarki.20240208.013509.970251/output...
# 5250.4	"26"
# 5253.3200000000015	"62"
# 5254.659999999998	"33"
# 5259.920000000003	"24"
# 5265.750000000001	"93"
# 5288.689999999996	"64"
# 5290.409999999998	"90"
# 5298.090000000002	"55"
# 5322.649999999999	"9"
# 5330.8	"34"
# 5337.44	"72"
# 5368.249999999999	"70"
# 5368.83	"43"
# 4765.05	"31"
# 4812.489999999998	"82"
# 4815.050000000002	"4"
# 4819.700000000001	"10"
# 4830.549999999999	"88"
# 4836.859999999999	"20"
# 4851.479999999999	"89"
# ...
