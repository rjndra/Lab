# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'p')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.plot(xpoints, ypoints,'o--r', ms=20, mec='b',mfc='hotpink')

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()

# %%
plt.plot(x1, y1, x2, y2)
# Out:
# [<matplotlib.lines.Line2D at 0x1328b2050>,
#  <matplotlib.lines.Line2D at 0x1328b2e10>]

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data", fontdict = font1)
plt.title("Sports", fontdict = font1, loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)
plt.plot(x, y)
plt.grid(color = 'r', linestyle = '--', linewidth = 1)
plt.show()

# %%
x = np.array([5,7,8,7,2,17])
y = np.array([99,86,87,88,111,86])
cols = np.array(["red","green","blue","yellow","pink","black"])
plt.scatter(x, y, c = cols)

# %%
x = np.array([5,7,8,7,2,17])
y = np.array([99,86,87,88,111,86])
sizes = np.array([20,50,100,200,500,1000])
plt.scatter(x, y, s = sizes, alpha = 0.3)

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y, color = "blue")
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x, y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x,y, color = "blue", width = 0.4)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
x = [1,1,2,3,3,5,7,8,9,10,
10,11,11,13,13,15,16,17,18,18,
18,19,20,21,21,23,24,24,25,25,
25,25,26,26,26,27,27,27,27,27,
29,30,30,31,33,34,34,34,35,36,
36,37,37,38,38,39,40,41,41,42,
43,44,45,45,46,47,48,48,49,50,
51,52,53,54,55,55,56,57,58,60,
61,63,64,65,66,68,70,71,72,74,
75,77,81,83,84,87,89,90,90,91
]
plt.hist(x, bins = 5)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [35, 25, 25, 15]
plt.pie(x)
plt.show()

# %%
x = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(x, labels = mylabels)
# Out:
# ([<matplotlib.patches.Wedge at 0x135b01810>,
#   <matplotlib.patches.Wedge at 0x135b19310>,
#   <matplotlib.patches.Wedge at 0x135b1a590>,
#   <matplotlib.patches.Wedge at 0x135b19d10>],
#  [Text(0.4993895680663529, 0.9801071672559597, 'Apples'),
#   Text(-1.086457168210212, 0.17207795223283892, 'Bananas'),
#   Text(-0.172077952232839, -1.086457168210212, 'Cherries'),
#   Text(0.9801071672559598, -0.49938956806635254, 'Dates')])

# %%
plt.pie(x, labels = mylabels, startangle = 90)
# Out:
# ([<matplotlib.patches.Wedge at 0x135bee450>,
#   <matplotlib.patches.Wedge at 0x135beec90>,
#   <matplotlib.patches.Wedge at 0x135befc90>,
#   <matplotlib.patches.Wedge at 0x135bfca10>],
#  [Text(-0.9801071672559597, 0.49938956806635293, 'Apples'),
#   Text(-0.172077952232839, -1.086457168210212, 'Bananas'),
#   Text(1.086457168210212, -0.17207795223283906, 'Cherries'),
#   Text(0.49938956806635265, 0.9801071672559598, 'Dates')])

# %%
x = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
plt.pie(x, labels = mylabels, startangle = 90, explode = myexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x135c32490>,
#   <matplotlib.patches.Wedge at 0x135c32f10>,
#   <matplotlib.patches.Wedge at 0x135c33f50>,
#   <matplotlib.patches.Wedge at 0x135c44f50>],
#  [Text(-1.1583084703934068, 0.5901876713511444, 'Apples'),
#   Text(-0.172077952232839, -1.086457168210212, 'Bananas'),
#   Text(1.086457168210212, -0.17207795223283906, 'Cherries'),
#   Text(0.49938956806635265, 0.9801071672559598, 'Dates')])

# %%
x = [35, 25, 25, 15]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(x, colors = mycolors)
# Out:
# ([<matplotlib.patches.Wedge at 0x135c47cd0>,
#   <matplotlib.patches.Wedge at 0x135c823d0>,
#   <matplotlib.patches.Wedge at 0x135c83150>,
#   <matplotlib.patches.Wedge at 0x135c83d90>],
#  [Text(0.4993895680663529, 0.9801071672559597, ''),
#   Text(-1.086457168210212, 0.17207795223283892, ''),
#   Text(-0.172077952232839, -1.086457168210212, ''),
#   Text(0.9801071672559598, -0.49938956806635254, '')])

# %%
x = [35, 25, 25, 15]
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(x)
plt.legend(title = "Four Fruits", labels = mylabels)
