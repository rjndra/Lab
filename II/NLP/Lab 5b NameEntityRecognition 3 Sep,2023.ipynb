# %% [markdown]
# **Title**: Name Entity Recognition (NER)
#
# **Author**: Rajendra Karki

# %%
text2 = '''
After streamlining the agenda, senior officials of the foreign ministry will sit with the Chinese side in Kathmandu and discuss possible agenda for agreement and signing in Beijing, said Govinda Acharya, press adviser to Prime Minister Dahal.

Chinese Ambassador Cheng Song has met Prime Minister Dahal, urging him to decide on the visit agenda so as to avoid last-minute hassles, which is a regular trend in Nepal’s diplomacy especially during high-level visits. Ambassador Cheng and Prime Minister Dahal on Friday morning discussed the need to expedite decisions on the agenda, according to the prime minister’s private secretariat.

Two officials from the Prime Minister’s Office and the Ministry of Foreign Affairs said there was a long list of items received from various ministries for bilateral consideration with China. “As of now, we expect at least six memoranda of understanding to be signed during the visit,” officials familiar with the preparations said. They range from agreeing on the text of the BRI project implementation plan and exporting buffalo meat to China, to opening more border points and new north-south corridors.
'''

# %%
text = '''
The Ministry of Foreign Affairs is busy preparing the agenda for the upcoming China visit of Prime Minister Pushpa Kamal Dahal, with inputs from various other ministries.

According to one secretary at the Prime Minister’s Office, as many as 100 proposals have been gathered so far. They will be processed by Sunday and a shortlist prepared for discussion with the Chinese authorities.

After completing his engagements around the 78th session of the United Nations General Assembly in New York, the prime minister is scheduled to visit China from September 23. In this trip, to be undertaken directly from the United States, Dahal is expected to meet Chinese President Xi Jinping and Chinese Premier Li Qiang, among other top officials.
'''

# %%
import nltk
tokens = nltk.word_tokenize(text)
len(tokens)
# Out:
# 132

# %% [markdown]
# Part of Speech NLTK.

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('The', 'DT'),
#  ('Ministry', 'NNP'),
#  ('of', 'IN'),
#  ('Foreign', 'NNP'),
#  ('Affairs', 'NNP'),
#  ('is', 'VBZ'),
#  ('busy', 'JJ'),
#  ('preparing', 'VBG'),
#  ('the', 'DT'),
#  ('agenda', 'NN')]

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/rajendrakarki/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/rajendrakarki/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/rajendrakarki/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Name Entities( NE) chuncks: ne_chunk
entries = nltk.chunk.ne_chunk(tagged)
print(entries[0])
print(entries[1])
# Out:
# ('The', 'DT')
# (ORGANIZATION Ministry/NNP)

# %%
for entry in entries:
    if hasattr(entry, 'label') and entry.label() == 'ORGANIZATION':
        print(f'{entry.label() } => {entry}')
        print(''.join(en[0]) for en in entry)
# Out:
# ORGANIZATION => (ORGANIZATION Ministry/NNP)
# <generator object <genexpr> at 0x10d621ee0>
# ORGANIZATION => (ORGANIZATION Foreign/NNP Affairs/NNP)
# <generator object <genexpr> at 0x10d621ee0>
# ORGANIZATION => (ORGANIZATION United/NNP Nations/NNP)
# <generator object <genexpr> at 0x10d621ee0>

# %%
#spacy
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users
lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.3.0)
# Requirement already satisfied: jinja2 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.6.3 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.6.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rajendrakarki/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
text = '''
Prime Minister Pushpa Kamal Dahal will not be short of agenda during his upcoming China trip.

The Ministry of Foreign Affairs is busy preparing the agenda for the upcoming China visit of Prime Minister Pushpa Kamal Dahal, with inputs from various other ministries.

According to one secretary at the Prime Minister’s Office, as many as 100 proposals have been gathered so far. They will be processed by Sunday and a shortlist prepared for discussion with the Chinese authorities.

After completing his engagements around the 78th session of the United Nations General Assembly in New York, the prime minister is scheduled to visit China from September 23. In this trip, to be undertaken directly from the United States, Dahal is expected to meet Chinese President Xi Jinping and Chinese Premier Li Qiang, among other top officials.

The prime minister has instructed Foreign Minister NP Saud and other senior officials of the foreign ministry to submit the agendas forwarded by various ministries by Sunday so that the government can pick what to take up, discuss, agree upon and sign with the Chinese government.

According to one minister, the Nepali side is keen on taking forward some projects under the Belt and Road Initiative (BRI) mostly in grants and concessional loan, but will likely stay away from other Chinese initiatives like the Global Security Initiative (GSI) and the Global Civilisation Initiative (GCI), both of which were recently floated by Chinese President Xi Jinping.

'As the GSI is a security initiative, our stated foreign policy makes it difficult for us to agree with it,' the minister said. “As China is already engaged in plenty of cultural and soft power diplomacy in Nepal, we need not be a part of the GCI.”

The Chinese are expected to request Nepal to agree on the GSI, the GCI and its Global Development Initiative (GDI). Nepal has already received two projects under the GDI which aligns with the UN’s Sustainable Development Goals.

After streamlining the agenda, senior officials of the foreign ministry will sit with the Chinese side in Kathmandu and discuss possible agenda for agreement and signing in Beijing, said Govinda Acharya, press adviser to Prime Minister Dahal.

# GPE => China
# ORG => The Ministry of Foreign Affairs
# GPE => China
# PERSON => Pushpa Kamal Dahal
# CARDINAL => one
# ORG => the Prime Minister’s Office
# CARDINAL => as many as 100
# DATE => Sunday
# NORP => Chinese
# ORDINAL => 78th
# ORG => the United Nations General Assembly
# GPE => New York
# GPE => China
# DATE => September 23
# GPE => the United States
# GPE => Dahal
# NORP => Chinese
# PERSON => Xi Jinping
# NORP => Chinese
# PERSON => Li Qiang
# PERSON => NP Saud
# ORG => the foreign ministry
# DATE => Sunday
# NORP => Chinese
# CARDINAL => one
# NORP => Nepali
# FAC => the Belt and Road Initiative
# PERSON => BRI
# NORP => Chinese
# ORG => the Global Security Initiative
# ORG => GSI
# ORG => the Global Civilisation Initiative
# ORG => GCI
# NORP => Chinese
# PERSON => Xi Jinping
# ORG => GSI
# GPE => China
# GPE => Nepal
# ORG => GCI
# NORP => Chinese
# PERSON => Nepal
# ORG => GSI
# ORG => GCI
# ORG => Global Development Initiative
# PERSON => Nepal
# CARDINAL => two
# ORG => GDI
# ORG => the UN’s Sustainable Development Goals
# ORG => the foreign ministry
# NORP => Chinese
# GPE => Kathmandu
# GPE => Beijing
# PERSON => Govinda Acharya
# PERSON => Dahal
# NORP => Chinese
# PERSON => Cheng Song
# PERSON => Dahal
# TIME => last-minute
# GPE => Nepal
# PERSON => Cheng
# PERSON => Dahal
# DATE => Friday
# TIME => morning
# CARDINAL => Two
# ORG => the Ministry of Foreign Affairs
# GPE => China
# CARDINAL => at least six
# ORG => BRI
# GPE => China
# PERSON => Dahal
# DATE => Friday
# NORP => Chinese
# FAC => the Hilsa-Simkot
# GPE => Korola
# GPE => Mustang
# GPE => Gorkha
# ORG => Socialist Front
# GPE => Pokhara
# DATE => Friday
# GPE => China
# GPE => Pokhara
# GPE => Bhairawaha
# NORP => Chinese
# PERSON => Dahal
# GPE => China
# GPE => Nepal
# GPE => China
# NORP => Nepali
# GPE => China
# ORG => BRI
# CARDINAL => at least one
# ORG => BRI
# GPE => Nepal
# ORG => Dahal
# PERSON => Nepal
# ORG => BRI
# FAC => the Pokhara International Airport
# CARDINAL => five
# GPE => China
# GPE => China
# GPE => Pokhara
# GPE => Bhairahawa
# NORP => Chinese
# ORG => the Ministry of Culture, Tourism and Civil Aviation
# ORG => The Ministry of Physical Infrastructure
# FAC => the Kimathanka-Khandbari
# QUANTITY => 162 km
# PERSON => Dhulikhel-Tatopani
# ORG => Araniko Highway
# QUANTITY => 84 km
# ORG => Khutiya-Dipayal-Chainpur-Taklakot
# QUANTITY => 269 km
# ORG => Tokha-Chhahare Tunnel
# ORG => the Ministry of Foreign Affairs
# CARDINAL => two
# GPE => Kathmandu Valley
# QUANTITY => 454-megawatt
# ORG => the Ministry of Communication and Information Technology
# CARDINAL => over half a dozen
# ORG => Dahal’s
# PERSON => Acharya
# NORP => Nepali
# PERSON => Yari
# PERSON => Kimathanka
# PERSON => Korala
# ORG => the Nepal-China Transit and Transportation Agreement
# DATE => 2016
# GPE => Gorkha
# GPE => Bajhang
# PERSON => Darchula
# GPE => Nepal
# GPE => China
# ORG => the Ministry of Industry and Commerce
# ORG => the ministry of foreign affairs
# DATE => Saturday
# NORP => Chinese
# CARDINAL => seven
# PERSON => Saud

# %%
ents = [
    (
        e.text, e.start_char, e.end_char, e.label_
    ) for e in doc.ents
]
print(ents)
# Out:
# [('Pushpa Kamal Dahal', 16, 34, 'PERSON'), ('China', 83, 88, 'GPE'), ('The Ministry of Foreign Affairs', 96, 127, 'ORG'), ('China', 174, 179, 'GPE'), ('Pushpa Kamal Dahal', 204, 222, 'PERSON'), ('one', 281, 284, 'CARDINAL'), ('the Prime Minister’s Office', 298, 325, 'ORG'), ('as many as 100', 327, 341, 'CARDINAL'), ('Sunday', 405, 411, 'DATE'), ('Chinese', 461, 468, 'NORP'), ('78th', 527, 531, 'ORDINAL'), ('the United Nations General Assembly', 543, 578, 'ORG'), ('New York', 582, 590, 'GPE'), ('China', 633, 638, 'GPE'), ('September 23', 644, 656, 'DATE'), ('the United States', 703, 720, 'GPE'), ('Dahal', 722, 727, 'GPE'), ('Chinese', 748, 755, 'NORP'), ('Xi Jinping', 766, 776, 'PERSON'), ('Chinese', 781, 788, 'NORP'), ('Li Qiang', 797, 805, 'PERSON'), ('NP Saud', 886, 893, 'PERSON'), ('the foreign ministry', 924, 944, 'ORG'), ('Sunday', 1002, 1008, 'DATE'), ('Chinese', 1096, 1103, 'NORP'), ('one', 1130, 1133, 'CARDINAL'), ('Nepali', 1148, 1154, 'NORP'), ('the Belt and Road Initiative', 1206, 1234, 'FAC'), ('BRI', 1236, 1239, 'PERSON'), ('Chinese', 1318, 1325, 'NORP'), ('the Global Security Initiative', 1343, 1373, 'ORG'), ('GSI', 1375, 1378, 'ORG'), ('the Global Civilisation Initiative', 1384, 1418, 'ORG'), ('GCI', 1420, 1423, 'ORG'), ('Chinese', 1465, 1472, 'NORP'), ('Xi Jinping', 1483, 1493, 'PERSON'), ('GSI', 1504, 1507, 'ORG'), ('China', 1628, 1633, 'GPE'), ('Nepal', 1703, 1708, 'GPE'), ('GCI', 1739, 1742, 'ORG'), ('Chinese', 1750, 1757, 'NORP'), ('Nepal', 1782, 1787, 'PERSON'), ('GSI', 1804, 1807, 'ORG'), ('GCI', 1813, 1816, 'ORG'), ('Global Development Initiative', 1825, 1854, 'ORG'), ('Nepal', 1862, 1867, 'PERSON'), ('two', 1889, 1892, 'CARDINAL'), ('GDI', 1912, 1915, 'ORG'), ('the UN’s Sustainable Development Goals', 1934, 1972, 'ORG'), ('the foreign ministry', 2026, 2046, 'ORG'), ('Chinese', 2065, 2072, 'NORP'), ('Kathmandu', 2081, 2090, 'GPE'), ('Beijing', 2148, 2155, 'GPE'), ('Govinda Acharya', 2162, 2177, 'PERSON'), ('Dahal', 2211, 2216, 'PERSON'), ('Chinese', 2219, 2226, 'NORP'), ('Cheng Song', 2238, 2248, 'PERSON'), ('Dahal', 2272, 2277, 'PERSON'), ('last-minute', 2335, 2346, 'TIME'), ('Nepal', 2384, 2389, 'GPE'), ('Cheng', 2450, 2455, 'PERSON'), ('Dahal', 2475, 2480, 'PERSON'), ('Friday', 2484, 2490, 'DATE'), ('morning', 2491, 2498, 'TIME'), ('Two', 2611, 2614, 'CARDINAL'), ('the Ministry of Foreign Affairs', 2662, 2693, 'ORG'), ('China', 2796, 2801, 'GPE'), ('at least six', 2825, 2837, 'CARDINAL'), ('BRI', 2988, 2991, 'ORG'), ('China', 3050, 3055, 'GPE'), ('Dahal', 3119, 3124, 'PERSON'), ('Friday', 3133, 3139, 'DATE'), ('Chinese', 3183, 3190, 'NORP'), ('the Hilsa-Simkot', 3220, 3236, 'FAC'), ('Korola', 3300, 3306, 'GPE'), ('Mustang', 3315, 3322, 'GPE'), ('Gorkha', 3341, 3347, 'GPE'), ('Socialist Front', 3501, 3516, 'ORG'), ('Pokhara', 3520, 3527, 'GPE'), ('Friday', 3531, 3537, 'DATE'), ('China', 3601, 3606, 'GPE'), ('Pokhara', 3715, 3722, 'GPE'), ('Bhairawaha', 3727, 3737, 'GPE'), ('Chinese', 3751, 3758, 'NORP'), ('Dahal', 3768, 3773, 'PERSON'), ('China', 3781, 3786, 'GPE'), ('Nepal', 3834, 3839, 'GPE'), ('China', 3898, 3903, 'GPE'), ('Nepali', 3925, 3931, 'NORP'), ('China', 4011, 4016, 'GPE'), ('BRI', 4060, 4063, 'ORG'), ('at least one', 4141, 4153, 'CARDINAL'), ('BRI', 4154, 4157, 'ORG'), ('Nepal', 4169, 4174, 'GPE'), ('Dahal', 4196, 4201, 'ORG'), ('Nepal', 4225, 4230, 'PERSON'), ('BRI', 4260, 4263, 'ORG'), ('the Pokhara International Airport', 4360, 4393, 'FAC'), ('five', 4436, 4440, 'CARDINAL'), ('China', 4455, 4460, 'GPE'), ('China', 4497, 4502, 'GPE'), ('Pokhara', 4506, 4513, 'GPE'), ('Bhairahawa', 4518, 4528, 'GPE'), ('Chinese', 4564, 4571, 'NORP'), ('the Ministry of Culture, Tourism and Civil Aviation', 4585, 4636, 'ORG'), ('The Ministry of Physical Infrastructure', 4639, 4678, 'ORG'), ('the Kimathanka-Khandbari', 4711, 4735, 'FAC'), ('162 km', 4742, 4748, 'QUANTITY'), ('Dhulikhel-Tatopani', 4751, 4769, 'PERSON'), ('Araniko Highway', 4776, 4791, 'ORG'), ('84 km', 4793, 4798, 'QUANTITY'), ('Khutiya-Dipay ...

# %%
spacy.displacy.render(doc, style='ent')

# spacy.displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>Prime Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pushpa Kamal Dahal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will not be short of agenda during his upcoming
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  trip.<br><br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Ministry of Foreign Affairs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is busy preparing the agenda for the upcoming
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  visit of Prime Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pushpa Kamal Dahal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , with inputs from various other ministries.<br><br>According to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  secretary at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Prime Minister’s Office
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     as many as 100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  proposals have been gathered so far. They will be processed by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sunday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and a shortlist prepared for discussion with the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  authorities.<br><br>After completing his engagements around the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     78th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  session of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Nations General Assembly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , the prime minister is scheduled to visit
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . In this trip, to be undertaken directly from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dahal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is expected to meet
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Xi Jinping
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Premier
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Li Qiang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , among other top officials.<br><br>The prime minister has instructed Foreign Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NP Saud
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and other senior officials of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the foreign ministry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to submit the agendas forwarded by various ministries by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0
